# %%
# Dependencies
import pandas as pd
from pathlib import Path
import glob as gb

# %%
files = gb.glob("Resources/*.csv")
df_list = []
for file in files:
    df = pd.read_csv(file, engine= 'python')
    df_list.append(df)

# %%
merged_df = pd.concat(df_list, names = ["merge_col"])

# %%
merged_df = pd.concat(df_list, axis = 1)

# %%
merged_df.head()
# Out:
#    PROP_DESC_ID  PROP_DESC_CODE PROP_DESC_NAME  WEAPON_ID WEAPON_CODE  \
# 0           1.0             1.0       Aircraft       21.0         11A
# 1           2.0             2.0        Alcohol       22.0         12A
# 2           3.0             3.0     Automobile       23.0         13A
# 3           4.0             4.0       Bicycles       24.0         14A
# 4           5.0             5.0          Buses       25.0         15A
#
#                  WEAPON_NAME SHR_FLAG  ASSIGNMENT_TYPE_ID  \
# 0        Firearm (Automatic)        N                 1.0
# 1        Handgun (Automatic)        N                 2.0
# 2          Rifle (Automatic)        N                 3.0
# 3        Shotgun (Automatic)        N                 4.0
# 4  Other Firearm (Automatic)        N                 5.0
#
#   ASSIGNMENT_TYPE_CODE                        ASSIGNMENT_TYPE_NAME  ...  \
# 0                    F                         Two-Officer Vehicle  ...
# ...
